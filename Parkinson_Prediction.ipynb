# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier 
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import metrics
from sklearn import preprocessing

# %%
data = pd.read_csv('test.csv')

# %%
data.head().transpose()
# Out:
#                  0          1         2         3          4
# ID              B1         B2        B3        B4         B5
# para_0    -0.71588   -0.39734    2.0094  -0.68993   0.079707
# para_1     -3.0044   -0.21463   0.83152  -0.29367    0.28115
# para_2      2.1178   -0.47653  -0.57052  -0.57052   0.067832
# para_3    -0.60143   -0.55927    2.2326  -0.65296   0.063937
# para_4      2.2159   0.070425    1.9654  -0.84061  -0.065041
# para_5    -0.53799    0.61432  0.032973  -0.33245   0.013117
# para_6     -1.7638   -0.30289   -1.7638   0.87885   0.052817
# para_7     0.26323   -0.41777  -0.82637   0.26323  -0.009172
# para_8    -0.21334  -0.071453  -0.70995   0.42516   -0.02981
# para_9    -0.64141   -0.64141  -0.64141  -0.50533   -0.36924
# para_10   -0.75881   -0.45263  -0.21061  -0.45905   -0.24512
# para_11   -0.27519   -0.33588  -0.37547  -0.26728   -0.20131
# para_12   -0.28431   -0.23381  -0.39405  0.004534   -0.16531
# para_13     0.5029    -1.9327   -1.4357   -0.2924     0.5029
# para_14     0.1433   -0.14958  -0.22235  -0.22379   -0.18596
# para_15   -0.62425    0.18735   -1.0659    1.2449    0.20945
# para_16   -0.12365   -0.15117 -0.073276  -0.15716   -0.15633
# para_17    -1.3014    0.58673   0.58673   -0.9867    0.58673
# para_18    0.31292   0.077258   0.41921   -1.2616    0.46347
# para_19    -1.3567    0.51334  -0.28811   -1.7129   -0.28811
# para_20  -0.016087 -0.0043393  -0.47803  -0.92853    0.31974
# para_21    0.75548   0.020912    1.4901   0.57184   0.020912
# para_22   -0.58954 -0.0027255   0.77344   0.73973  -0.011815
# para_23    0.48425  0.0033689   0.96512  -0.11684   -0.18898
# para_24   -0.74218   0.017856    1.1162   0.69664   -0.23238
# para_25   -0.53879    0.18967   0.18967  -0.48372    0.18967
# para_26   0.067861   0.089917   0.13296  -0.72039    0.28843
# para_27   -0.13974  -0.096837 -0.090153  -0.14175   -0.10735
# para_28   -0.17168  -0.085157 -0.063057   -0.3481   0.039718
# para_29   -0.44033   -0.44033    2.9199   0.74564   -0.14384
# para_30   -0.35758      2.737 -0.041807  -0.10496   -0.54705
# para_31     0.5029    -1.9327   -1.4357   -0.2924     0.5029
# para_32  -0.092482    0.12254 -0.092482  0.050869  -0.092482
# para_33    0.18591   -0.22559  -0.22559   0.18591   -0.22559
# para_34   -0.42105   -0.42105    1.3814   0.17978    0.98089
# para_35   -0.35232   -0.35232    0.8053  0.033554    0.54805
# para_36   0.032623   -0.23531   0.70617   -0.2745   -0.21731
# para_37    0.44044   -0.22542   0.34344  -0.39871  0.0043815
# para_38     0.1107   -0.18987   0.23556  -0.23958   -0.17022
# para_39     0.5972   -0.26431  -0.26431  -0.15662    0.16644
# para_40   0.032743   -0.24085   0.70293   -0.2822   -0.21964
# para_41  0.0071505    0.51981  -0.16374  -0.16374   -0.16374
# para_42   -0.11229    0.30551  -0.11229   0.09661   -0.11229
# para_43   -0.53451   -0.57834    2.4111  -0.57834   -0.44067
# para_44    -2.2743    -1.5976   0.99018  -0.42393   -0.43881
# para_45     2.0724   -0.54541  -0.54541  -0.54541   -0.51908
# para_46   -0.51227   -0.55678    2.4793  -0.55678   -0.45691
# para_47   -0.43436    -0.4899    3.0724   -0.4899   -0.36529
# para_48     1.0088   0.052101    2.2579   0.22958   -0.30419
# para_49   -0.46486    0.28711  -0.46486   0.70488    0.98631
# para_50   -0.87386   -0.14021   -2.1318  -0.44661  0.0049273

# %%
data.columns
# Out:
# Index(['ID', 'para_0', 'para_1', 'para_2', 'para_3', 'para_4', 'para_5',
#        'para_6', 'para_7', 'para_8', 'para_9', 'para_10', 'para_11', 'para_12',
#        'para_13', 'para_14', 'para_15', 'para_16', 'para_17', 'para_18',
#        'para_19', 'para_20', 'para_21', 'para_22', 'para_23', 'para_24',
#        'para_25', 'para_26', 'para_27', 'para_28', 'para_29', 'para_30',
#        'para_31', 'para_32', 'para_33', 'para_34', 'para_35', 'para_36',
#        'para_37', 'para_38', 'para_39', 'para_40', 'para_41', 'para_42',
#        'para_43', 'para_44', 'para_45', 'para_46', 'para_47', 'para_48',
#        'para_49', 'para_50'],
#       dtype='object')

# %%
data.shape
# Out:
# (500, 52)

# %% [markdown]
# ### We observe that there are 195 rows and 23 columns in the given dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 52 columns):
# ID         500 non-null object
# para_0     500 non-null float64
# para_1     500 non-null float64
# para_2     500 non-null float64
# para_3     500 non-null float64
# para_4     500 non-null float64
# para_5     500 non-null float64
# para_6     500 non-null float64
# para_7     500 non-null float64
# para_8     500 non-null float64
# para_9     500 non-null float64
# para_10    500 non-null float64
# para_11    500 non-null float64
# para_12    500 non-null float64
# para_13    500 non-null float64
# para_14    500 non-null float64
# para_15    500 non-null float64
# para_16    500 non-null float64
# para_17    500 non-null float64
# para_18    500 non-null float64
# para_19    500 non-null float64
# para_20    500 non-null float64
# para_21    500 non-null float64
# para_22    500 non-null float64
# para_23    500 non-null float64
# para_24    500 non-null float64
# para_25    500 non-null float64
# para_26    500 non-null float64
# para_27    500 non-null float64
# para_28    500 non-null float64
# para_29    500 non-null float64
# para_30    500 non-null float64
# para_31    500 non-null float64
# para_32    500 non-null float64
# para_33    500 non-null float64
# para_34    500 non-null float64
# para_35    500 non-null float64
# para_36    500 non-null float64
# para_37    500 non-null float64
# para_38    500 non-null float64
# para_39    500 non-null float64
# para_40    500 non-null float64
# para_41    500 non-null float64
# para_42    500 non-null float64
# para_43    500 non-null float64
# para_44    500 non-null float64
# para_45    500 non-null float64
# para_46    500 non-null float64
# para_47    500 non-null float64
# para_48    500 non-null float64
# para_49    500 non-null float64
# para_50    500 non-null float64
# dtypes: float64(51), object(1)
# memory usage: 203.2+ KB

# %% [markdown]
# From the above information, we observe that all the given features are continuous except 'status'(since given in the description).

# %%
data.describe().transpose()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# para_0   500.0  0.051567  0.934583 -1.105200 -0.594710 -0.193585  0.635460
# para_1   500.0  0.041878  1.070069 -3.559100 -0.033364  0.419310  0.822270
# para_2   500.0  0.013323  1.017532 -0.984110 -0.611880 -0.474750  0.296288
# para_3   500.0  0.063795  0.937550 -1.065200 -0.601430 -0.241270  0.479563
# para_4   500.0  0.093643  0.965379 -1.237900 -0.526537 -0.167435  0.634908
# para_5   500.0 -0.037808  0.890755 -0.880580 -0.608762 -0.307900  0.032973
# para_6   500.0 -0.068639  0.933012 -1.763800 -0.701120  0.225455  0.629630
# para_7   500.0 -0.005358  0.751000 -0.826370 -0.417770 -0.281570  0.399430
# para_8   500.0 -0.002268  0.987555 -0.709950 -0.332715 -0.201055  0.141380
# para_9   500.0 -0.062229  0.962303 -0.777500 -0.641410 -0.369240 -0.097070
# para_10  500.0 -0.124894  0.888116 -1.452000 -0.684505 -0.534550  0.356215
# para_11  500.0 -0.045680  0.573565 -0.388660 -0.333250 -0.280470 -0.139302
# para_12  500.0 -0.035997  0.889247 -0.474700 -0.286545 -0.203080 -0.052022
# para_13  500.0  0.008915  0.972355 -3.026300 -0.342110  0.453190  0.701720
# para_14  500.0 -0.019833  0.665618 -0.299370 -0.194360 -0.155985 -0.096932
# para_15  500.0  0.007222  1.000970 -1.771500 -0.749290  0.183540  0.565480
# para_16  500.0 -0.034061  0.965803 -0.160500 -0.158383 -0.157080 -0.141660
# para_17  500.0 -0.008823  1.064674 -2.154100 -1.112600  0.586730  0.586730
# para_18  500.0 -0.046199  1.101006 -2.692600 -0.998120  0.130920  0.419210
# para_19  500.0  0.063691  1.073314 -3.393800 -0.288110 -0.288110  0.513340
# para_20  500.0  0.036778  0.691894 -1.436900 -0.386030 -0.080393  0.160185
# para_21  500.0  0.030540  1.060482 -1.653900 -0.713660  0.020912  0.020912
# para_22  500.0  0.019410  0.887420 -2.137100 -0.392665 -0.022059  0.246702
# para_23  500.0 -0.039596  0.912685 -1.587200 -0.477500 -0.477500  0.099548
# para_24  500.0 -0.063032  0.849481 -1.096600 -0.480500 -0.355790  0.146902
# para_25  500.0 -0.040039  0.730954 -0.958770 -0.637640  0.189670  0.189670
# para_26  500.0 -0.035916  0.892266 -1.716100 -0.762705  0.059119  0.245292
# para_27  500.0 -0.071318  0.256742 -0.177400 -0.118230 -0.111110 -0.088506
# para_28  500.0 -0.055831  0.365088 -0.494890 -0.241117 -0.152865  0.012834
# para_29  500.0 -0.056078  0.865071 -0.440330 -0.440330 -0.440330 -0.143840
# para_30  500.0  0.024505  0.984609 -0.673350 -0.673350 -0.483890  0.337120
# para_31  500.0  0.008915  0.972355 -3.026300 -0.342110  0.453190  0.701720
# para_32  500.0 -0.026397  0.146334 -0.092482 -0.092482 -0.092482  0.050869
# para_33  500.0  0.032830  0.912689 -0.225590 -0.225590 -0.225590 -0.225590
# para_34  500.0  0.007543  0.956767 -0.421050 -0.421050 -0.421050 -0.020493
# para_35  500.0  0.098379  2.074622 -0.352320 -0.352320 -0.352320 -0.095070
# para_36  500.0 -0.057453  0.893941 -0.418530 -0.366895 -0.255960 -0.102930
# para_37  500.0 -0.044385  0.857649 -0.656770 -0.548460 -0.244260  0.142120
# para_38  500.0 -0.051566  0.919808 -0.371370 -0.323970 -0.215300 -0.081201
# para_39  500.0  0.014174  0.814697 -0.264310 -0.264310 -0.264310 -0.048934
# para_40  500.0 -0.057396  0.894933 -0.413690 -0.365185 -0.258340 -0.098485
# para_41  500.0 -0.041385  0.430010 -0.163740 -0.163740 -0.163740 -0.163740
# para_42  500.0 -0.019259  0.223435 -0.112290 -0.112290 -0.112290  0.026975
# para_43  500.0 -0.070281  0.934396 -0.578340 -0.578340 -0.522170 -0.214045
# para_44  500.0 -0.109136  1.054518 -2.403700 -0.688173  0.012751  0.990180
# para_45  500.0  0.007713  1.023051 -0.545410 -0.545410 -0.424565 -0.159820
# para_46  500.0 -0.069963  0.933297 -0.556780 -0.556780 -0.509530 -0.271520
# para_47  500.0 -0.058624  0.931807 -0.489900 -0.489900 -0.444675 -0.289145
# para_48  500.0  0.010326  0.909531 -0.784590 -0.573545 -0.320265  0.030732
# para_49  500.0  0.036922  1.105505 -0.464860 -0.464860 -0.312370  0.108442
# para_50  500.0 -0.021683  0.928685 -2.131800 -0.262955  0.200055  0.651963
#
#               max
# para_0    2.00940
# para_1    0.83152
# para_2    2.73810
# para_3    2.64480
# para_4    2.36620
# para_5    3.81770
# para_6    1.42230
# para_7    5.03020
# para_8   10.14100
# para_9    2.89680
# para_10   3.97110
# para_11   2.45590
# para_12  11.42800
# para_13   0.75143
# para_14   6.82430
# para_15   3.20810
# para_16  16.63000
# para_17   3.41890
# para_18   4.83680
# para_19   6.92500
# para_20   4.47900
# para_21   9.57040
# para_22   8.40630
# para_23   7.31260
# para_24   9.41810
# para_25   4.75850
# para_26   5.34460
# para_27   4.07520
# para_28   4.41780
# para_29   6.28010
# para_30   3.93690
# para_31   0.75143
# para_32   1.55600
# para_33   6.76980
# para_34   7.59000
# para_35  38.10600
# para_36  13.35200
# para_37  11.59000
# para_38  14.65300
# para_39   8.24320
# para_40  13.37500
# para_41   3.59580
# para_42   1.90710
# para_43   2.41110
# para_44   0.99018
# para_45   3.45760
# para_46   2.47930
# para_47   3.29820
# para_48   2.25790
# para_49   9.56150
# para_50   0.93219

# %%
data[data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, para_0, para_1, para_2, para_3, para_4, para_5, para_6, para_7, para_8, para_9, para_10, para_11, para_12, para_13, para_14, para_15, para_16, para_17, para_18, para_19, para_20, para_21, para_22, para_23, para_24, para_25, para_26, para_27, para_28, para_29, para_30, para_31, para_32, para_33, para_34, para_35, para_36, para_37, para_38, para_39, para_40, para_41, para_42, para_43, para_44, para_45, para_46, para_47, para_48, para_49, para_50]
# Index: []
#
# [0 rows x 52 columns]

# %% [markdown]
# From the above two cells,we observe that there are no missing values in the given dataset

# %% [markdown]
# Most are having Parkinson disease. The ratio is almost 1:3 in favor of status 1. So, the model's ability to predict status 1 will be better than predicting status 0.

# %%
data = pd.read_csv('test.csv')
data1 = pd.read_csv('train.csv')
array = data.values
X = array[:,0:52]
array1 = data1.values
Y= array1[:,0:53]

# %%
#Splitting the data into train and test in 70/30 ratio with random state as 2.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-68821ca8d2a2> in <module>
#       1 #Splitting the data into train and test in 70/30 ratio with random state as 2.
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(data,data1)
#
# C:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2182         test_size = 0.25
#    2183
# -> 2184     arrays = indexable(*arrays)
#    2185
#    2186     if shuffle is False:
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     258         else:
#     259             result.append(np.array(X))
# --> 260     check_consistent_length(*result)
#     261     return result
#     262
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [500, 1529]

# %% [markdown]
# # LogisticRegression

# %%
LR = LogisticRegression()
LR.fit(X_train, Y_train)
Y1_predict = LR.predict(X_test)
Y_acc = metrics.accuracy_score(Y_test,Y1_predict)
print("Accuracy of the model is {0:2f}".format(Y_acc*100))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy of the model is 81.355932

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#Splitting the data into train and test in 70/30 ratio with random state as 2.
array = data.values
X = array[:,0:22]
Y = array[:,22]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)

# %%
R = RandomForestClassifier()
R.fit(X_train, Y_train)
Y1_predict = R.predict(X_test)
Y_acc = metrics.accuracy_score(Y_test,Y1_predict)
print("Accuracy of the model is {0:2f}".format(Y_acc*100))
# Out:
# Accuracy of the model is 79.661017
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
array = data.values
X = array[:,0:22]
Y = array[:,22]
#Splitting the data into train and test in 70/30 ratio with random state as 2.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)
G = GaussianNB()
G.fit(X_train, Y_train)
Y1_predict = G.predict(X_test)
Y_acc = metrics.accuracy_score(Y_test,Y1_predict)
print("Accuracy of the model is {0:2f}".format(Y_acc*100))
# Out:
# Accuracy of the model is 62.711864

# %% [markdown]
# # LinearDiscriminantAnalysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
array = data.values
X = array[:,0:22]
Y = array[:,22]
#Splitting the data into train and test in 70/30 ratio with random state as 2.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=2)
LD = LinearDiscriminantAnalysis()
LD.fit(X_train, Y_train)
Y1_predict = LD.predict(X_test)
Y_acc = metrics.accuracy_score(Y_test,Y1_predict)
print("Accuracy of the model is {0:2f}".format(Y_acc*100))
# Out:
# Accuracy of the model is 81.355932

# %%
data.head()
# Out:
#         Fo      Fhi      Flo  Jitter(%)  Jitter(Abs)      RAP      PPQ  \
# 0  119.992  157.302   74.997    0.00784      0.00007  0.00370  0.00554
# 1  122.400  148.650  113.819    0.00968      0.00008  0.00465  0.00696
# 2  116.682  131.111  111.555    0.01050      0.00009  0.00544  0.00781
# 3  116.676  137.871  111.366    0.00997      0.00009  0.00502  0.00698
# 4  116.014  141.781  110.655    0.01284      0.00011  0.00655  0.00908
#
#        DDP  Shimmer  Shimmer(dB)   ...        DDA      NHR     HNR      RPDE  \
# 0  0.01109  0.04374        0.426   ...    0.06545  0.02211  21.033  0.414783
# 1  0.01394  0.06134        0.626   ...    0.09403  0.01929  19.085  0.458359
# 2  0.01633  0.05233        0.482   ...    0.08270  0.01309  20.651  0.429895
# 3  0.01505  0.05492        0.517   ...    0.08771  0.01353  20.644  0.434969
# 4  0.01966  0.06425        0.584   ...    0.10470  0.01767  19.649  0.417356
#
#         DFA   spread1   spread2        D2       PPE  status
# 0  0.815285 -4.813031  0.266482  2.301442  0.284654       1
# 1  0.819521 -4.075192  0.335590  2.486855  0.368674       1
# 2  0.825288 -4.443179  0.311173  2.342259  0.332634       1
# 3  0.819235 -4.117501  0.334147  2.405554  0.368975       1
# 4  0.823484 -3.747787  0.234513  2.332180  0.410335       1
#
# [5 rows x 23 columns]

# %%
p=R.predict([[
119.992,157.302,74.997,0.00784,0.00007,0.0037,0.00554,0.01109,0.04374,0.426,0.02182,0.0313,0.02971,0.06545,0.02211,21.033,0.414783,0.815285,-4.813031,0.266482,2.301442,0.284654
]])

# %%
print(p)
# Out:
# [1.]

# %%
data.tail()
# Out:
#           Fo      Fhi     Flo  Jitter(%)  Jitter(Abs)      RAP      PPQ  \
# 190  174.188  230.978  94.261    0.00459      0.00003  0.00263  0.00259
# 191  209.516  253.017  89.488    0.00564      0.00003  0.00331  0.00292
# 192  174.688  240.005  74.287    0.01360      0.00008  0.00624  0.00564
# 193  198.764  396.961  74.904    0.00740      0.00004  0.00370  0.00390
# 194  214.289  260.277  77.973    0.00567      0.00003  0.00295  0.00317
#
#          DDP  Shimmer  Shimmer(dB)   ...        DDA      NHR     HNR  \
# 190  0.00790  0.04087        0.405   ...    0.07008  0.02764  19.517
# 191  0.00994  0.02751        0.263   ...    0.04812  0.01810  19.147
# 192  0.01873  0.02308        0.256   ...    0.03804  0.10715  17.883
# 193  0.01109  0.02296        0.241   ...    0.03794  0.07223  19.020
# 194  0.00885  0.01884        0.190   ...    0.03078  0.04398  21.209
#
#          RPDE       DFA   spread1   spread2        D2       PPE  status
# 190  0.448439  0.657899 -6.538586  0.121952  2.657476  0.133050       0
# 191  0.431674  0.683244 -6.195325  0.129303  2.784312  0.168895       0
# 192  0.407567  0.655683 -6.787197  0.158453  2.679772  0.131728       0
# 193  0.451221  0.643956 -6.744577  0.207454  2.138608  0.123306       0
# 194  0.462803  0.664357 -5.724056  0.190667  2.555477  0.148569       0
#
# [5 rows x 23 columns]

# %%
pr=LD.predict([[198.764,396.961,74.904,0.0074,0.00004,0.0037,0.0039,0.01109,0.02296,0.241,0.01265,0.01321,0.01588,0.03794,0.07223,19.02,0.451221,0.643956,-6.744577,0.207454,2.138608,0.123306
]])

# %%
print(pr)
# Out:
# [0.]

# %%
B=([['MDVP:Fo(Hz)','MDVP:Fhi(Hz)','MDVP:Flo(Hz)','MDVP:Jitter(%)','MDVP:Jitter(Abs)','MDVP:RAP','MDVP:PPQ','Jitter:DDP','MDVP:Shimmer','MDVP:Shimmer(dB)','Shimmer:APQ3','Shimmer:APQ5','MDVP:APQ','Shimmer:DDA','NHR','HNR','RPDE','DFA','spread1','spread2','D2','PPE'
]])

# %%
R=int(1)
C=int(22)
matrix=[]
for i in range(R):
    d=[]
    for j in range(C):
        print(B[i][j],end=" ")
        d.append(float(input()))
        matrix.append(d)
# Out:
# MDVP:Fo(Hz) 198.764
# MDVP:Fhi(Hz) 396.961
# MDVP:Flo(Hz) 74.904
# MDVP:Jitter(%) 0.00740
# MDVP:Jitter(Abs) 0.00004
# MDVP:RAP 0.00370
# MDVP:PPQ 0.00390
# Jitter:DDP 0.01109
# MDVP:Shimmer 0.02296
# MDVP:Shimmer(dB) 0.241
# Shimmer:APQ3 0.01265
# Shimmer:APQ5 0.01321
# MDVP:APQ 0.01667
# Shimmer:DDA 0.03794
# NHR 0.07223
# HNR 19.02
# RPDE 0.451221
# DFA 0.643956
# spread1 -6.74458
# spread2 0.207454
# D2 2.138608
# PPE 0.123306

# %%
matrix
# Out:
# [[198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306],
#  [198.764,
#   396.961,
#   74.904,
#   0.0074,
#   4e-05,
#   0.0037,
#   0.0039,
#   0.01109,
#   0.02296,
#   0.241,
#   0.01265,
#   0.01321,
#   0.01667,
#   0.03794,
#   0.07223,
#   19.02,
#   0.451221,
#   0.643956,
#   -6.74458,
#   0.207454,
#   2.138608,
#   0.123306]]

# %%
a=LD.predict(matrix)
z=int(a[1])
if z==1 :
    print("predict algorithm")
else:
     print("yes or no")
# Out:
# person don't have parkison disease
